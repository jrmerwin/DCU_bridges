# %% [markdown]
# # New vertical bridges
# Runs the original self-contained cells from the repository. Each script generates its own fixed output directory. This notebook does not duplicate or change the model code.

# %%
from pathlib import Path
import runpy
ROOT = Path.cwd()
if not (ROOT / "code/cells").is_dir():
    ROOT = ROOT.parent
assert (ROOT / "code/cells").is_dir(), "Open from the repository or notebooks directory."

# %%
cell38 = runpy.run_path(str(ROOT / "code/cells/DCU_Mass_Cell_38.py"))
dcu_mass_38 = cell38["dcu_mass_38"]

# %%
cell39 = runpy.run_path(str(ROOT / "code/cells/DCU_Mass_Cell_39.py"))
dcu_mass_39 = cell39["dcu_mass_39"]
